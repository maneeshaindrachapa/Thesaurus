# %%
import pandas as pd
synonyms = pd.read_excel('def_new_col_many.xlsx')

# %%
dictionary = {}
for i in range(synonyms['Word'].size):
    word = str(synonyms.loc[i]['Word'])
    definition = synonyms.loc[i]['Def1']
    if (word!='' and definition!=''):
        dictionary[word] = definition
vocab = list(dictionary.keys())
vocab
# Out:
# ['\ufeffඅ ',
#  'අංකනය ',
#  'අංකය, අඞ්කය ',
#  'අංකිත ',
#  'අංකීරා, අංකූරා (කථා) ',
#  'අං කූටය ',
#  'අංකුරය, අඞ්කුරය ',
#  'අංකුශ වාරණය ',
#  'අංගම ',
#  'අංගම් පොරය ',
#  'අංගය, අඞ්ගය ',
#  'අංග රාගය, අඞ්ග රාගය ',
#  'අංග විද්\u200dයාව ',
#  'අංගහීන ',
#  'අංගාගී ',
#  'අංගාරකය ',
#  'අංගාරකරණය (පාරිභා.) ',
#  'අංගාර මාංසය',
#  'අංගාරය, අඞ්ගාරය',
#  'අංගාරිකාම්ලය ',
#  'අංගයි ',
#  'අංගරී ස',
#  'අංගුට්ට (කථා.) ',
#  'අංගුත්තර නිකාය ',
#  'අංජනම, අඤ්ජනම ',
#  'අංජනය, අඤ්ජනය ',
#  'අංජලපි ටු ය, අඤජ් ලපි ටු ය ',
#  'අංජලයි , අඤජ් ලයි ',
#  'අංශය ',
#  'අකටයතු ු',
#  'අකණ ',
#  'අකර ',
#  'අකර්මණ්\u200dය ',
#  'අකල්් ',
#  'අකලල් කයා ',
#  'අකාබනික (පාරිභා.) ',
#  'අකාල ',
#  'අකාලවාදි ',
#  'අකාලික ',
#  'අකිංචන, අකිඤ්චන ',
#  'අකිරිය වාදය ',
#  'අකුතෝභය ',
#  'අකුර ',
#  'අකුරට ',
#  'අකුල ',
#  'අකුළනවා ',
#  'අකෘතඥයා ',
#  'අක් උවටා ',
#  'අක්කරම්, අක්කාරම් ',
#  'අක්කරය ',
#  'අකක් ැමියා',
#  'අක්ත පත\u200d්\u200dරය ',
#  'අක් දෙරිය ',
#  'අක්පතළය, අක්පතළාව',
#  'අක්පිටුව ',
#  'අක්මුල් ',
#  'අක\u200d්\u200dරිය අංකුරය (පාරිභා.) ',
#  'අක\u200d්\u200dරිය වාතය (පාරිභා.) ',
#  'අකයි\u200d්\u200dර ාව ',
#  'අක්වටය (පාරිභා.) ',
#  'අක්ෂකාස්ථිය ',
#  'අක්ෂ භේදය ',
#  'අක්ෂය ',
#  'අක්ෂර කෞශල්\u200dයය ',
#  'අක්ෂර දෝෂය ',
#  'අක්ෂර වින්\u200dයාසය ',
#  'අක්ෂරාගමය ',
#  'අක්ෂරාභ්\u200dයාසය ',
#  'අක්ෂරෝච්චාරණය ',
#  'අකෂ් ාංශය ',
#  'අක්ෂි කාචය (පාරිභා.) ',
#  'අක්ෂිකාධරය (පාරිභා.) ',
#  'අකෂ් ි කටූ ය ',
#  'අක්ෂි කූපය ',
#  'අක්ෂි ගුලය, අක්ෂි ගෝලය ',
#  'අක්ෂි පක්ෂ්මය ',
#  'අකෂ් ි පටලය (පාරිභා.) ',
#  'අක්ෂි පථය ',
#  'අක්ෂි පුටය ',
#  'අක්ෂි ලපය (පාරිභා.) ',
#  'අක්ෂි විෂය ',
#  'අග',
#  'අග උවටා',
#  'අගත ',
#  'අග තනතුර',
#  'අග තිත ',
#  'අගතයි ',
#  'අගද',
#  'අග නුවර ',
#  'අග බමුණා ',
#  'අග බිම ',
#  'අග බිසව, අග බිසොව',
#  'අගම්මැටි (පාරිභා.) ',
#  'අගම්යෝගය (පාරිභා.) ',
#  'අගය කරනවා ',
#  'අගය වඩනවා ',
#  'අගරුක ',
#  'අගල, අගළ ',
#  'අග වරුව ',
#  'අගසස් දන් ',
#  'අගහර ',
#  'අගාධ ',
#  'අගාධ ගොහොරුව (පාරිභා.) ',
#  'අගාර කුඹුර ',
#  'අගාර විනය',
#  'අගාරික',
#  'අගාරිය',
#  'අගියාව (කථා.) ',
#  'අගරිි ගානවා (කථා.) ',
#  'අගිස්සනවා (කථා.) ',
#  'අගලු ් කණවු , අගුුඵ කණවු ',
#  'අගුල් තට්ටුව, අගුළු තට්ටුව ',
#  'අගලු ප් ත් ',
#  'අගවු ',
#  'අගුළු ඉද්ද ',
#  'අගොස ',
#  'අගොච් ර ',
#  'අග්ගින්න ',
#  'අග්ඝාපනික',
#  'අග්ඝිකාව ',
#  'අග්නි කණිකා ',
#  'අග්නි කර්මය ',
#  'අගන් ි කාෂඨ් ය',
#  'අග්නි කෝණය ',
#  'අග්නිදීපක ',
#  'අග්නි දීපනය ',
#  'අග්නි දේවතාවා ',
#  'අගන් ි ධරය ',
#  'අග්නිධර්ම ',
#  'අගන් ි ධාතවු ',
#  'අග්නි පාෂාණය ',
#  'අගන් ි භධූ රය',
#  'අග්නි මණ්ඩලය ',
#  'අග්නි මන්දය, අග්නි මාන්ද්\u200dයය ',
#  'අග්නි මානය (පාරිභා.) ',
#  'අගන් යි ',
#  'අගන් ි රකෂ් ණය ',
#  'අග්නිසංගය, අග්නිසඞ්ගය ',
#  'අග්නි ස්කන්ධය ',
#  'අග්නි ස්තම්භනය, අග්නි ස්තම්භය ',
#  'අග්නි ස්ථානය ',
#  'අග්නි හෝත\u200d්\u200dරය ',
#  'අග්න්\u200dයුන්මාදය (පාරිභා.) ',
#  'අග\u200d්\u200dරකය (පාරිභා.) ',
#  'අග\u200d්\u200dරකාය ',
#  'අග\u200d්\u200dරගණ්\u200dයයා ',
#  'අග\u200d්\u200dරජ ',
#  'අග\u200d්\u200dරජයා ',
#  'අග\u200d්\u200dරදක්ෂිණාර්හ ',
#  'අග\u200d්\u200dර දානය ',
#  'අග\u200d්\u200dර ඳුතයා ',
#  'අග\u200d්\u200dර දෙවී් ',
#  'අග\u200d්\u200dර ඵලය ',
#  'අග\u200d්\u200dර බාහුව ',
#  'අග\u200d්\u200dර භෝජනය ',
#  'අග\u200d්\u200dරරාජගුරැ ',
#  'අග\u200d්\u200dරරාජගුරුප\u200d්\u200dරසාදි ',
#  'අග\u200d්\u200dර විනශි ච් යකාරයා ',
#  'අග\u200d්\u200dර ශ\u200d්\u200dරාවකයා ',
#  'අග\u200d්\u200dරශ\u200d්\u200dරී ',
#  'අග\u200d්\u200dරසරැ, අග්\u200dරේසර ',
#  'අගහ\u200d්\u200dර ාරය',
#  'අග\u200d්\u200dරාංගුලිය ',
#  'අගා\u200d්\u200dරසනය ',
#  'අගමි\u200d්\u200dර කම\u200d්\u200dර ය (පාරිභා.) ',
#  'අග\u200d්\u200dරිමය (පාරිභා.) ',
#  'අගේ\u200d්\u200dරශයා (පාරිභා.) ',
#  'අග්\u200dරෝදකය ',
#  'අග්\u200dරෝපාසිකාව ',
#  'අඟපසඟ ',
#  'අඟර ',
#  'අඟවනවා ',
#  'අුගුටු මස්ස ',
#  'අුගටු මිු ට්ටා ',
#  'අුගුට්ට ',
#  'අඟරු ැ ',
#  'අුගරු ැ මස',
#  'අුගරු ැ මැළය ',
#  'අඟුල ',
#  'අුගලු ් මානය ',
#  'nan',
#  'අචලතාප (පාරිභා.) ',
#  'අචල භූමිය',
#  'අචලලක්ෂ්\u200dය (පාරිභා.) ',
#  'අචල ස්වර ',
#  'අචිනත් ක',
#  'අචිත්තජ ',
#  'අචිතත් කී ෘත',
#  'අචිනේ තය්\u200dය',
#  'අචින්තෙය්\u200dයරෑපී ',
#  'අචිනත් ්\u200dය ',
#  'අචිර ',
#  'අචේතසකි , අචේතසක් ',
#  'අචේලකයා ',
#  'එරස්කත සංයෝගය ',
#  'අච්චය',
#  'අච්චාරුව ',
#  'අච්චු අකරු ැ ',
#  'අච්චු කඳ ',
#  'අච්චු කූර',
#  'අච්චු මුද්\u200dරණය (පාරිභා.) ',
#  'අච්චු ලෑලල් ',
#  'අච්චුව ',
#  'අච්ඡුකාස්ථිය (පාරිභා.) ',
#  'අච්ඡුන්දික ',
#  'අච්ýන්න ධාරාව ',
#  'අජගව ',
#  'අජ පථය ',
#  'අජල ',
#  'අජීරණය, අජීර්ණය ',
#  'අජීව උපත (පාරිභා.) ',
#  'අජීව ලෝකය ',
#  'අජීවෝත්පන්න ',
#  'අජ්ඣත්තික නිදානය ',
#  'අජ්ඣත්තික රෑප ',
#  'අජ්ඣාචාරය ',
#  'අඥාතයා ',
#  'අඥාන විජෘම්භණය ',
#  'අඥානාත්මක ',
#  'අඥානෝපේක්ෂාව ',
#  'අඤ්ඤභාගී, අඤ්ඤභාගීය ',
#  'අඤ්ඤමඤ්ඤපච්චය ',
#  'අඤඤ් මඤඤ් ය ',
#  'අට ',
#  'අට අඟ ',
#  'අට අරිපුුගෙු ලා් ',
#  'අටං පහුර, අටන් පහුර, අටම් පහුර (කථා.) ',
#  'අට කර',
#  'අට කලන්ය ',
#  'අටක් ',
#  'අට ගණය ',
#  'අට ගුණය ',
#  'අටඟ මිණ ',
#  'අටන (කථා.) ',
#  'අට නැණ ',
#  'අට නෙත ',
#  'අටපද ',
#  'අට පහ ',
#  'අට මගල, අට මඟල ',
#  'අට මුග ',
#  'අටමස්ථානය ',
#  'අටමහ ලෝ වැඩ ',
#  'අට යොන්, අට යෝනි ',
#  'අටලූ ගෙය ',
#  'අට ලෝ දහම ',
#  'අටල්ල ',
#  'අටවක',
#  'අටවක මිණ, අටවක් මැණික ',
#  'අටවනවා ',
#  'අට වරල (කථා.) ',
#  'අටස්, අටැස් ',
#  'අටළොස් ආවේණික ධර්ම ',
#  'අටළොස් කුලය ',
#  'අටුමැස්ස ',
#  'අටුව ',
#  'අට්ටවාලය ',
#  'අට්ටාලය (පාරිභා.) ',
#  'අට්ඨපු ප් තත් යි ',
#  'අඩ ',
#  'අඩකුඹු කරනවා ',
#  'අඩ කුළුදුල, අඩ කුළුදුල්ල ',
#  'අඩතල ',
#  'අඩ තැන්න ',
#  'අඩදිටි ',
#  'අඩ නනි ද් ',
#  'අඩ පය ',
#  'අඩප්පරය ',
#  'අඩ මත ',
#  'අඩ මස ',
#  'අඩ මස්ස ',
#  'අඩයාලම ',
#  'අඩයාලම් කොඩිය ',
#  'අඩල, අඩළ ',
#  'අඩලා ගනන් වා (කථා.) ',
#  'අඩව්ව ',
#  'අඩසඳ / අඩහඳ ',
#  'අඩස් බැල්ම ',
#  'අඩස්සි පොල්ල (කථා.) ',
#  'එරස්කිය ',
#  'අඩාළ කරනවා ',
#  'අඩාළ පොහොය ',
#  'අඩිංචිය (කථා.) ',
#  'අඩි කෝඩය, අඩිකෝඩෙ ',
#  'අඩිතාලම ',
#  'අඩිපලූ බොය් ',
#  'අඩි පාර ',
#  'අඩි මඩකක් වු (කථා.) ',
#  'අඩි මාත\u200d්\u200dරය (කථා.) ',
#  'අඩිවට්ටම (කථා.) ',
#  'අඩි හප්පනවා (කථා.) ',
#  'අඩු ',
#  'අඩුක්කුව ',
#  'භෝජනය. - ',
#  'අඩුක්කු සප්පායම (කථා.) ',
#  'අඩතු ත් ු ',
#  'අඩුව',
#  'අණ ',
#  'අණ කරනවා ',
#  'අණඟිල්ල, අණැුගිල්ල (කථා.) ',
#  'අණ තහනම ',
#  'අණ පණවි ඩු ',
#  'අණ පාමොක් (විනය.) ',
#  'අණ පොල්ල ',
#  'අණසක ',
#  'අණසුන්පත ',
#  'අණිමා ',
#  'අණිලනවා ',
#  'අණුක ආකර්ෂණය (පාරිභා.) ',
#  'අණුක කම්පනය (පාරිභා.) ',
#  'අණුක ක්ෂේතය\u200d්\u200dර (පාරිභා.) ',
#  'අණුක ඝනත්වය (පාරිභා.) ',
#  'අණුක වාදය ',
#  'අණකු සතූ ය\u200d්\u200dර ',
#  'අණදු කන් ය ',
#  'අණුව',
#  'අණ්ඩ ',
#  'අණ්ඩ කෝෂය ',
#  'අණ්ඩජ ',
#  'අණ්ඩජයා ',
#  'අණ්ඩධානිය (පාරිභා.) ',
#  'අණ්ඩපය ',
#  'අණඩ් පාතය ',
#  'අණ්ඩ මෝචනය ',
#  'අණ්ඩ වාතය, අණ්ඩ වායුව ',
#  'අණ්ඩ ෙසෙලය ',
#  'අණ්ඩාකාර ගවාක්ෂය (පාරිභා.) ',
#  'අණ්ඩාණුධානිය (පාරිභා.) ',
#  'අණඩ් ාශය, අණඩ් ාසය(පාරිභා.) ',
#  'අණ්ඩෝද්භවය ',
#  'අණ්වීක්ෂය ',
#  'අඬසන',
#  'අඬහැරය, අඬහැරේ ',
#  'අඬා බසිනවා ',
#  'අඬාරය (කථා.) ',
#  'අඬුපඬු ',
#  'අඬුබරියා (කථා.) ',
#  'අඬු මැස්සා ',
#  'අඬුව ',
#  'අඬෝරය (කථා.) ',
#  'අත ',
#  'අතඋඩ (කථා.) ',
#  'අතකුළුව, අතකොුඵව ',
#  'අතක්කාවචර ',
#  'අතපත්තුව ',
#  'අතපුර ',
#  'අතරමැදි',
#  'අතලස්පර්ශ ',
#  'අතවරු ැ, අතඋරැ, අැතොවරු ැ ',
#  'අතාත්ත්වික ',
#  'අතාවුද ',
#  'අතකි ාල ',
#  'අතික\u200d්\u200dරමණය, අතික\u200d්\u200dරමය ',
#  'අතිජාත ',
#  'අතධ්ි වනයි ',
#  'අතිපණ්ඩිත ',
#  'අතිමඤ්ඤනාව ',
#  'අතිරක්තය',
#  'අතිරස, අතිරහ ',
#  'අතිරික්ත ',
#  'අතිරේකය',
#  'අතිව්\u200dයාප්තිය ',
#  'අතිශක්මතාව (පාරිභා.) ',
#  'අතශි යොක් ත් යි ',
#  'අතිසත්වාදය (පාරිභා.) ',
#  'අතිසේක (පාරිභා.) ',
#  'අතිස\u200d්\u200dරාවය ',
#  'අතිස්වේදය ',
#  'අතිහරණය ',
#  'අතිහසිතය\t',
#  'අතීක්ෂ්ණ ',
#  'අතීත ',
#  'අතීතකාල ක\u200d්\u200dරියාව ',
#  'අතතී ඥානය ',
#  'අතීතාරම්මණ, අතීතාලම්බන ',
#  'අතුණු බහන ',
#  'අතු බැඳීම (පාරිභා.) ',
#  'අතු මීය (කථා.) ',
#  'අතුරැ ',
#  'අතුරු ආබාධය ',
#  'අතුරුණවු (පාරිභා.) ',
#  'අතුරැ බත ',
#  'අතරු ැමග, අතරු ැ මුග',
#  'අතුරැ ව්\u200dයවස්ථාව ',
#  'අතුල ',
#  'අතුවැල (කථා.) ',
#  'අතුසන, අතුහන ',
#  'අතක් ම ',
#  'අත් කොළය ',
#  'අත්ගල ',
#  'අතග් හ (කථා.)',
#  'අත් ගුණය ',
#  'අතත් නයි , අතත් නයී ',
#  'අත්තම ',
#  'අත්තවාදය ',
#  'අතත් සඤඤ් ා ',
#  'අතත් ා ',
#  'අතත් කි ාරම ',
#  'අතථ් ාවහ',
#  'අත්ථි සුඛය ',
#  'අත් දණ්ඩ, අත්දඬුව, අද්දණ්ඩ ',
#  'අත්දඬුවාව ',
#  'එඑරස්කම, අද්දැකීම ',
#  'අත් නලූ ',
#  'අත් පුඩරු ',
#  'අත්පතල, අත්පතලය, අත්පතලාව ',
#  'අතප් ස',
#  'අත්පසුර, අත්පහුර ',
#  'අත්පිට ',
#  'අතප් ඩිි , අතප් ඩි ,ු අතප් ුිඩු ',
#  'අත්පිස්නාව ',
#  'අතප් ටු ',
#  'අත්පුටුව ',
#  'අත් පොරය ',
#  'අත් පොත ',
#  'අතබ් නදි් ',
#  'අත් බමරය, අත් බඹරය ',
#  'අත්බඹ (කථා.) ',
#  'අතබ් ර',
#  'අත් බැලීම ',
#  'අත් බොම්් බය ',
#  'අත්මග, අත්මුග ',
#  'අත්මත ',
#  'අත්මල්ල ',
#  'අතම් ානම',
#  'අතමි් ට',
#  'අත්\u200dයණුක ',
#  'අත්\u200dයන්ත ',
#  'අත්මිටි හරඹය ',
#  'අත්මිණි ',
#  'අත් මුදල',
#  'අත් මෙහෙය ',
#  'අත්\u200dයන්තෝපකාර, අත්\u200dයනේ තාප් කාරක ',
#  'අත්යන්ත\u200d්\u200dරය ',
#  'අත්\u200dයල්ප ',
#  'අත්\u200dයල්පමාත\u200d්\u200dර ',
#  'අත්\u200dයුත්සන්නතාව ',
#  'අත්\u200dයුද්ගත ',
#  'අත්\u200dයුද්වේග ',
#  'අත\u200d්\u200dරජ',
#  'අත්රස ',
#  'අත\u200d්\u200dරාණ ශාලාව ',
#  'අතච්ි\u200d්\u200dර ඡු ',
#  'අත් රිය',
#  'අත\u200d්\u200dරිලිඞ්ග',
#  'අත් රෝධකය(පාරිභා.) ',
#  'අත්ලස ',
#  'අත්ලීය (කථා.) ',
#  'අත්වරද, අත්වැරැුද්ද ',
#  'අත්වාරාව (කථා.) ',
#  'අත්වාසයි ',
#  'අත්වැට ',
#  'අත්වැඩ ',
#  'අත්වැඩකරුවා ',
#  'අත්වැඩ සාදනවා ',
#  'අත්වැදවිය, අත්වැදෑවිය ',
#  'අතව් ැල',
#  'අත් වෙදකම (කථා.) ',
#  'අත් විදීම',
#  'අතස් තර ',
#  'අත්සන ',
#  'අත්සර ',
#  'අත් හරිනවා ',
#  'අත්හැන්ද ',
#  'අතහ් රු ැ ',
#  'අත් හොදි් සයි ',
#  'අථර්ව, අථර්වන් ',
#  'අථල',
#  'අථාවර ',
#  'අද ඇති ',
#  'අදත්තාදාන පරිභෝගය ',
#  'අදත්තාදානය ',
#  'අදන් ',
#  'අදනත් ',
#  'අදර ',
#  'අදරකිරිය',
#  'අදරවිබත් ',
#  'අදස ',
#  'අදහනවා, අදානවා ',
#  'අදහම ',
#  'අදහස් උදහස් ',
#  'අදහැනි ',
#  'අදාරනවා ',
#  'අදාළ ',
#  'අදිකයා ',
#  'අදිකාරම      ',
#  'අදිටන ',
#  'අදිනවා ',
#  'අදින්නාදානය ',
#  'අදිප්පුව ',
#  'අදිවේද ඳුතයා ',
#  'අදිශ රාශයි (පාරිභා.) ',
#  'අදීප්ත ',
#  'අදීප්ත දැල්ල (පාරිභා.) ',
#  'අදුක්ඛමසුඛ වේදනා ',
#  'අදුතිය ',
#  'අඳුර දෘෂ්ටිය ',
#  'අදෘෂට් මිතය\u200d්\u200dර ා',
#  'අදෙස් ',
#  'අදේව දෘෂ්ටිය ',
#  'අද්ධාන ගමන ',
#  'අදධ් ාන පරිච්ෙඡ්දය',
#  'අද්භූතය ',
#  'අදභ් තූ ධමය_ ',
#  'අද්මිරල්, අද්මිරාල් ',
#  'අද්\u200dයතන',
#  'අද්\u200dරවණශීල, අද්\u200dරවණශීලී (පාරිභා.) ',
#  'අදව් කාත් ',
#  'අද්වයවාදී ',
#  'අධඃකෘත ',
#  'අධඃපටු ය (පාරිභා.) ',
#  'අධඃශීර්ෂ ',
#  'අධර ',
#  'අධර්ම කර්මය ',
#  'අධර්ම චෝදකයා ',
#  'අධර්ම වෙළඳාම් පස ',
#  'අධශ්ශිරස් ',
#  'අධික අවුරුද්ද ',
#  'අධිකතම පදය(පාරිභා.) ',
#  'අධිකරණ බලපත\u200d්\u200dරය ',
#  'අධිකරණය ',
#  'අධිකරණයී ',
#  'අධික රුධිර පීඩනය (පාරිභා.) ',
#  'අධිකාධික ',
#  'අධිකාර පෙ\u200d්\u200dර දශ් ය ',
#  'අධිකාරී ',
#  'අධිකාර්ථ ',
#  'අධික්ෂිප්ත ',
#  'අධිගතයා ',
#  'අධිගමය ',
#  'අධිතපත් (පාරිභා.) ',
#  'අධිතාපනය (පාරිභා.) ',
#  'අධිතක්සේරැව (පාරිභා.) ',
#  'අඑරස්කා ',
#  'අධිබල ',
#  'අධි මාසය ',
#  'අධිමුක්තිය ',
#  'අධිමූර්ඡුාව ',
#  'අධිමොක්ඛය, අධිමෝක්ෂය ',
#  'අධියර ',
#  'අධිරෑඪ',
#  'අධිරෝපණය (පාරිභා.) ',
#  'අධිවාසනය ',
#  'අධිවෘක්ක ග\u200d්\u200dරන්ථිය (පාරිභා.) ',
#  'අධිශලී ය, අධිසලී ය (පාරිභා.) ',
#  'අධිෂ්ඨිත ',
#  'අධෝගතයා ',
#  'අධෝ බින්දුව (පාරිභා.) ',
#  'අධෝ විරේචනය ',
#  'අධෝශීර්ෂ ',
#  'අධ්\u200dයයන පරිපාටිය ',
#  'අධ්\u200dයවස්තරණය ',
#  'අධ්\u200dයවස්තෘත ',
#  'අධ්\u200dයශනය ',
#  'අධ්\u200dයාත්ම ',
#  'අධ්\u200dයාතම් ලොක් ය ',
#  'අධ්\u200dයාත්ම වාදය ',
#  'අධ්\u200dයාපන විද්\u200dයාව ',
#  'අධ්\u200dයායාසය ',
#  'අධ්\u200dයාහාරය ',
#  'අධ්\u200dයාහෘත',
#  'අධේ\u200dය්ෂක ',
#  'අධ්වක්ෂම ',
#  'අනග ',
#  'අනග පෙි යස',
#  'අනඞ්ග පීඩාව ',
#  'අනත ',
#  'අනතිචාරිණී ',
#  'අනතිධාවනය ',
#  'අනද ',
#  'අනතිවත්තන, අනතිවර්තන ',
#  'අනතරු ැ',
#  'අනධිගතය ',
#  'අනධ්\u200dයාචරණය ',
#  'අනධ්වනිය ',
#  'අනන්ත ',
#  'අනන්තජින ',
#  'අනන්තබුද්ධි ',
#  'අනන්තරනිරුද්ධ ',
#  'අනනත් රායකි ',
#  'අනන්\u200dය ',
#  'අනන්\u200dයතා පත\u200d්\u200dරය (පාරිභා.) ',
#  'අනන්\u200dයතාව ',
#  'අනන්\u200dයපත\u200d්\u200dර ෙි බාධි් ත',
#  'අනන්\u200dයාර්ථ ',
#  'අනපත\u200d්\u200dරපාව ',
#  'අනභිප\u200d්\u200dරාය ',
#  'අනභිෂික්තයා ',
#  'අනභිසංස්කෘත ',
#  'අනමතග්ග ',
#  'අනය ',
#  'අනර්ඝ ',
#  'අනර්ථ පරිහාරය ',
#  'අඑරස්කලක ',
#  'අනර්ථසංහිත ',
#  'අනර්ථාවහ ',
#  'අනවමදර්ශී ',
#  'අනවරණ ',
#  'අනවරත ',
#  'අනවරතේ ',
#  'අනවලෝක්\u200dය ',
#  'අනහ ',
#  'අනහත්',
#  'අනා ',
#  'අනාගත දර්ශයි ා ',
#  'අනාගත ධර්මය',
#  'අනාගතභාවී',
#  'අනාගතවක්තෘ',
#  'අනාගත වාක්\u200dයය ',
#  'අනාගාමී ඵලය ',
#  'අනාචාරය ',
#  'අනාචාරි ',
#  'අනාචාරියා ',
#  'අනාත්ම ලක්ෂණය ',
#  'අනාත්මවාදය ',
#  'අනාදෙය්\u200dය, අනාදෙය් ',
#  'අනාද්\u200dයන්ත ',
#  'අනානන්තර ',
#  'අනාපතත් යි ',
#  'අනාපාථය ',
#  'අනාමන්තචාරය ',
#  'අනාමර්ශ ',
#  'අනාමෘෂ්ට ',
#  'අනායාස ',
#  'අනාරම්මණ',
#  'අනාර්ය',
#  'අනාර්යයා',
#  'අනාලම්බ ',
#  'අනාලය ',
#  'අනාවරකය (පාරිභා.) ',
#  'අනාවරණ ඥානය ',
#  'අනාසෙවි් ත ',
#  'අනිකේත ',
#  'අනිච්ච ',
#  'අනිච්ඡු ',
#  'අනිච්ඡුානුග (පාරිභා.) ',
#  'අනිච්ýත කර්මය ',
#  'අනිත්\u200dය ',
#  'අනිත්\u200dයානුදර්ශනය ',
#  'අනිදර්ශන, අනිදස්සන ',
#  'අනිධානගත ',
#  'අනිනවා ',
#  'අනින්දිත ',
#  'අනනි ද්\u200dර් යි ',
#  'අනිබද්ධ ',
#  'අනිබද්්ධවාස ',
#  'අනිබද්ධ සයනය ',
#  'අනෙි ම්ෂයා ',
#  'අනියත මිථ්\u200dයාදෘෂ්ටිය ',
#  'අනියම ',
#  'අනියම භාගය(පාරිභා.) ',
#  'අනියමාර්ථය ',
#  'අනියම් සිතාසි දීම ',
#  'අනියා ',
#  'අනයි ා කැබැලි ',
#  'අනිරුද්ධ ',
#  'අනිර්ණේයතාව (පාරිභා.) ',
#  'අනිර්දිෂ්ට ',
#  'අනිවතුන් ',
#  'අනිවරණ ',
#  'එරස්කර්ය ',
#  'අනිවාර්ය විෂය ',
#  'අනිෂ්ට සමෝධානය ',
#  'අනෂි ට් ාර්ථය ',
#  'අනිෂ්ටාලම්බනය ',
#  'අනතී කි ',
#  'අනිස්තිර (කථා.) ',
#  'අනිස්සිත ',
#  'අනීකට්ඨයා ',
#  'අනීශ්චර ',
#  'අනු',
#  'අනුකථනය ',
#  'අනුකථාව ',
#  'අනුකම්පාව ',
#  'අනුකරණය ',
#  'අනුකලනය\t(පාරිභා.) ',
#  'අනකු ලාව ',
#  'අනුකාර්ය ',
#  'අනුකිරිය ',
#  'අනුකූලනය ',
#  'අනුකෘතිය ',
#  'අනුකෘත්\u200dයය ',
#  'අනකු ඛි් තත් ',
#  'අනුක\u200d්\u200dරම ',
#  'අනුක\u200d්\u200dරමණිකාව ',
#  'අනකු ම\u200d්\u200dර ාඞ්කනය ',
#  'අනුගත ',
#  'අනුගාමිනි,\tඅනුගාමී ',
#  'අනුගාමීසඞ්ඛ්\u200dයා (පාරිභා.) ',
#  'අනුගායනාව ',
#  'අනුගෘහිත ',
#  'අනුජ ',
#  'අනුඥාත ',
#  'අනුට්ඨාන සෙය්\u200dයාව ',
#  'අනුතීර ',
#  'අනතු රු ැ ',
#  'අනුත්තර ',
#  'අනුත්තරියධර්ම ',
#  'අනතු ත් ාන ',
#  'අනුත්සාහය',
#  'අනුදාත්තය (ව්\u200dයාක.) ',
#  'අනුදිග ',
#  'අනුදත් ',
#  'අනුනය ',
#  'අනුනා ',
#  'අනුධ\u200d්\u200dරැවය (පාරිභා.) ',
#  'අනුනද ',
#  'අනුපනීත ',
#  '\ufeffඅනුපම, අනූපම ',
#  'අනුපස්සනාව ',
#  'අනුපාතය ',
#  'අනුපාතික, අනුපාති (පාරිභා.) ',
#  'අනුපාදානය ',
#  'අනුපුබ්බඞ්ගුලිතා',
#  'අනුපූට්ටුව ',
#  'අනපු ර්ූ වකථා',
#  'අනපු භ\u200d්\u200dර ව',
#  'අනුප\u200d්\u200dරව\u200d්\u200dරජිත ',
#  'අනුප\u200d්\u200dරසවකාල     (පාරිභා.)     ',
#  'අනුප\u200d්\u200dරාප්තිය ',
#  'අනුප\u200d්\u200dරියභාණී ',
#  'අනුබද්ධ ',
#  'අනුබන්ධනය ',
#  'අනුබන්ධය ',
#  'අනුබඳ ',
#  'අනුබලය ',
#  'අනුභව වස්තුව ',
#  'අනුභාවය',
#  'අනුභූතපූර්ව ',
#  'අනුභූතිය ',
#  'අනුමරණය ',
#  'අනුමානය ',
#  'අනුමිතිය ',
#  'අනුමෙවෙනි බණ ',
#  'අනෙු ම්ය',
#  'අනුයාත ',
#  'අනුයුඤ්ජනය ',
#  'අනුයෝගය ',
#  'අනුලේඛන ',
#  'අනුලේපනය ',
#  'අනුලෝම ',
#  'අනුවර්තිනී ',
#  'අනුවාදිත ',
#  'අනුවාසනය ',
#  'අනුවිවෘත්ත ',
#  'අනවු ෘතත් යි ',
#  'අනුවෙනවා ',
#  'අනුව්\u200dයඤ්ජනය ',
#  'අනුශයාවස්ථ ',
#  'අනුශාසනය, අනුශාසනාව, අනුසාසනය, අනුසාසනාව ',
#  'අනුශීර්ෂය ',
#  'අනුෂඤ්ජනය ',
#  'අනූන ',
#  'අනූනාධික ',
#  'අනූප',
#  'අඑරස්කර්ථ ',
#  'අනේවාදහස් ',
#  'අනෝදිස්සක ',
#  'අනග් තකි යා',
#  'අන්තඃපුති ',
#  'අන්තගුණ ',
#  'අන්තධ\u200d්\u200dරැවය (පාරිභා.) ',
#  'අනත් ර',
#  'අන්තර මකරන්ද මිශ\u200d්\u200dරණය (පාරිභා.) ',
#  'අන්තරස්ථ ',
#  'අන්තරාගාමිකයා ',
#  'අන්තරායකර ',
#  'අන්තරායකර ධර්ම ',
#  'අන්තරාලය ',
#  'අන්තරාල වෙළඳාම (පාරිභා.) ',
#  'අන්තරාවර්ති (පාරිභා.) ',
#  'අන්තරාසර්ග (පාරිභා.) ',
#  'අන්තරිත ',
#  'අන්තරින්ද්\u200dරිය ',
#  'අන්තරීක්ෂකේතු ',
#  'අන්තර්ගතික ',
#  'අන්තර් ග\u200d්\u200dරහණය ',
#  'අන්තර් ජන්තු (පාරිභා.) ',
#  'අන්තර්ජන්\u200dය ',
#  'අන්තර්ජාතික දාතම රේඛාව (පාරිභා.) ',
#  'අන්තර්යාමි',
#  'අන්තර් යෝගය (පාරිභා.) ',
#  'අන්තර්රාෂ්ටී\u200d්\u200dරය ',
#  'අන්තර්ලිඛිත වෘත්තය (පාරිභා.) ',
#  'අන්තර්ලිඞ්ග',
#  'අන්තර්වර්තනය (පාරිභා.) ',
#  'අනත් ර්වාහී (පාරිභා.) ',
#  'අන්තර්විවාහ ',
#  'අන්තර් වෘත්තය (පාරිභා.) ',
#  'අන්තවාද දෘෂ්ටි ',
#  'අන්තශ්චර්මය (පාරිභා.) ',
#  'අන්තසත ',
#  'අන්ත සතර ',
#  'අන්ත්\u200dය උපචය',
#  'අන්ත්\u200dයය ',
#  'අන්ත\u200d්\u200dර වෘද්ධිය ',
#  'අන්දම් තබනවා ',
#  'අන්දරකෙක්ක (කථා.) ',
#  'අන්දායම ',
#  'අන්දු, අන්ඳු ',
#  '\ufeffඅන්දුකය, අන්ඳුකය ',
#  'අන්ඳුබන්ධනය ',
#  'අන්ධවේණි පරම්පරාව ',
#  'අන්නනාළය ',
#  'අන්නා කොටවනවා (කථා.) ',
#  'අන්නප්පට්ටුව ',
#  'අන්නෑය, අන්නෑව, අැන්නෑව ',
#  'අන් බඳ ',
#  'අන්\u200dයගතික ',
#  'අනේ\u200dයා්න්\u200dයාධාරය ',
#  'අන්වද්ධමාස ',
#  'අන්වය ',
#  'අනව් ාධේය',
#  'අන්සතු ',
#  'අන්සීනයා, අංසීනයා ',
#  'අඳ ',
#  'අඳන ',
#  'අප ',
#  'අපකර්ෂණය (පාරිභා.) ',
#  'අපකෘත ',
#  'අපචය ',
#  'අපචේතෘ ',
#  'අපතේ යනවා ',
#  'අපත\u200d්\u200dරපා ',
#  'අපදන් ',
#  'අපද්\u200dරව්\u200dයය ',
#  'අපනයනය ',
#  'අපභාෂාව ',
#  'අප\u200d්\u200dරභ\u200d්\u200dරංශ, අපභ\u200d්\u200dරංස ',
#  'අපර',
#  'අපරගිර',
#  'අපරාරම්භය ',
#  'අපරිගෘහිත ',
#  'අපරිණත ',
#  'අපරිනායක',
#  'අපරිභූත ',
#  'අපරිමාණ ',
#  'අපරිමේය ',
#  'අපරිව්\u200dයක්ත ',
#  'අපල ',
#  '\ufeffඅපස්සය ',
#  'අපහෘත ',
#  'අපාය',
#  'අපාරගම්\u200dය (පාරිභා.) ',
#  'අපාශ\u200d්\u200dරය ',
#  'අපිකපාලය (පාරිභා.) ',
#  'අපිචර්මය (පාරිභා.) ',
#  'අපිජන්තු (පාරිභා.) ',
#  'අපිලාපන ',
#  'අපිස්සතොස් ',
#  'අපප් ණාව ',
#  'අප්පණිහිත ',
#  'අප්පවාරිතය ',
#  'අප\u200d්\u200dරමත්ත ',
#  'අපස\u200d්\u200dර නන් ',
#  'අප\u200d්\u200dරාණක ',
#  'අප\u200d්\u200dරාණිවාචක, අප\u200d්\u200dරාණිවාචි ',
#  'අබ ',
#  'අබතුර ',
#  'අබඳ ',
#  'අබබය ',
#  'අබය ',
#  'අබා ',
#  'අබ්බෝහාරික ',
#  'අබ්\u200dයංගය ',
#  'අබ්\u200dයාකත ධර්ම',
#  'අභයදානය ',
#  'අභයභූමිය ',
#  'අභය මුද්\u200dරාව ',
#  'අභය සංඥාව ',
#  'අභි ',
#  'අභික්කමන, අභික\u200d්\u200dරමණ, අභික\u200d්\u200dරම ',
#  'අභිඝාතය ',
#  'අභිචාරය ',
#  'අභිචින්තනය ',
#  'අභිජාත ',
#  'අභිජානන ',
#  'අභිජිත් ',
#  'අභිඥානය ',
#  'අභිඥේය ',
#  'අභිඤ්ඤාත ',
#  'අභිධර්ම පිටකය ',
#  'අභිධාව ',
#  'අභෙි ධය්\u200dය, අභෙි ධ්ය ',
#  'අභිනන්දනය ',
#  'අභිනය ',
#  'අභිනිවර්ජනය, අභිනිවර්තනය ',
#  'අභිනිවේශය, අභිනිවේසය ',
#  'අභිනීත',
#  'අම්මා']

# %%
def definition(word):
    for vocab_word in vocab:
        if word in vocab_word:
            return dictionary.get(vocab_word)
    return ''

# %%
definition("අම්මා")
# Out:
# 'අම්මා sasa'
