# %%
import pandas as pd 
import requests
import openpyxl
import numpy as np

# %%
f = open("../FastText_en_si/FastText/cc.en.300.vec",'r', encoding='utf-8')
# f = open("Output/Combined/tr.cc.si.300.vec",'r', encoding='utf-8')
data = f.readlines()
data = [a.split(" ", 1)[0] for a in data]
data= data[1:]
data.sort()
data

# %%
data = [s for s in data if (s.isalpha())]
data = set(data)
data = sorted(data)
data
# Out:
# ['AAAAAAAAAA',
#  'AAAAAAAAAAAA',
#  'AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA',
#  'AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA',
#  'AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA',
#  'AAAAAAAAH',
#  'AAAAAAAAt',
#  'AAAAAAAH',
#  'AAAAAAH',
#  'AAAAAHHHH',
#  'AAAAAHHHHH',
#  'AAAAAND',
#  'AAAAHHHHH',
#  'AAAAND',
#  'AAAB',
#  'AAACE',
#  'AAAG',
#  'AAAGH',
#  'AAAHHHHH',
#  'AAAND',
#  'AAAR',
#  'AAASAE',
#  'AAATA',
#  'AAAdministratorName',
#  'AABR',
#  'AABSyS',
#  'AABox',
#  'AACB',
#  'AACG',
#  'AACOG',
#  'AADB',
#  'AADCP',
#  'AADM',
#  'AADSM',
#  'AAEI',
#  'AAFB',
#  'AAFCS',
#  'AAFE',
#  'AAFld',
#  'AAGE',
#  'AAGolf',
#  'AAHHHH',
#  'AAHM',
#  'AAHSA',
#  'AAHospitality',
#  'AAIIIC',
#  'AAIP',
#  'AAIPharma',
#  'AAISP',
#  'AAIU',
#  'AAInformation',
#  'AAKASH',
#  'AALCO',
#  'AALE',
#  'AALU',
#  'AAMBC',
#  'AAMES',
#  'AAMET',
#  'AAMGA',
#  'AAMOF',
#  'AAMPLE',
#  'AANE',
#  'AANEM',
#  'AANHPI',
#  'AANM',
#  'AANMC',
#  'AANN',
#  'AANZFTA',
#  'AAOC',
#  'AAOE',
#  'AAOM',
#  'AAPAC',
#  'AAPE',
#  'AAPNA',
#  'AAPR',
#  'AAPW',
#  'AAPhysical',
#  'AARA',
#  'AARDA',
#  'AARGM',
#  'AARHUS',
#  'AARM',
#  'AARRGGHH',
#  'AARTS',
#  'AASHIQUI',
#  'AASWomen',
#  'AASs',
#  'AATH',
#  'AATP',
#  'AATs',
#  'AAUAAA',
#  'AAVA',
#  'AAVP',
#  'AAWA',
#  'AAWL',
#  'AAWP',
#  'AAWR',
#  'AAZV',
#  'AAdditional',
#  'AAdvantageAmerican',
#  'AAfter',
#  'AAh',
#  'AAre',
#  'AAt',
#  'AAtlanta',
#  'ABADI',
#  'ABAN',
#  'ABARTH',
#  'ABBC',
#  'ABBL',
#  'ABBREVIATION',
#  'ABBS',
#  'ABCABC',
#  'ABCCC',
#  'ABCDEFGH',
#  'ABCDEFGHIJKLMNOPQ',
#  'ABCDEFGHIJKLMNOPQRSTUVWxyZ',
#  'ABCDEFGHiJKLMNOPqRSTUVWXYZ',
#  'ABCE',
#  'ABCM',
#  'ABCMR',
#  'ABCN',
#  'ABCTE',
#  'ABCUSA',
#  'ABCpdf',
#  'ABCsGamingMoviesRantsIdiots',
#  'ABDClean',
#  'ABDComfortable',
#  'ABDComfy',
#  'ABDCountry',
#  'ABDD',
#  'ABDGreat',
#  'ABDHistoric',
#  'ABDLake',
#  'ABDLarge',
#  'ABDModern',
#  'ABDS',
#  'ABDSunny',
#  'ABDadmin',
#  'ABEA',
#  'ABEDA',
#  'ABEKA',
#  'ABEX',
#  'ABFFE',
#  'ABFRL',
#  'ABFS',
#  'ABFT',
#  'ABGA',
#  'ABGC',
#  'ABGL',
#  'ABHA',
#  'ABHINAV',
#  'ABHM',
#  'ABHOR',
#  'ABHOW',
#  'ABHR',
#  'ABHS',
#  'ABID',
#  'ABIHM',
#  'ABIN',
#  'ABIOMED',
#  'ABIX',
#  'ABJoe',
#  'ABKC',
#  'ABLATION',
#  'ABLES',
#  'ABLIS',
#  'ABMM',
#  'ABMR',
#  'ABNC',
#  'ABNEY',
#  'ABNL',
#  'ABNs',
#  'ABOARDThe',
#  'ABODA',
#  'ABOM',
#  'ABOP',
#  'ABOT',
#  'ABOUTCollege',
#  'ABOUTLos',
#  'ABOUTPro',
#  'ABOUTThe',
#  'ABOs',
#  'ABPMP',
#  'ABRAMOWITZ',
#  'ABRAXAS',
#  'ABRBIBBSOSBLOBGIDPERRDPOSBAll',
#  'ABRE',
#  'ABRIL',
#  'ABSDF',
#  'ABSENCES',
#  'ABSF',
#  'ABSITE',
#  'ABSM',
#  'ABSORBING',
#  'ABSTINENCE',
#  'ABSTRACTBackground',
#  'ABSTRACTThis',
#  'ABSTUDY',
#  'ABSYNTH',
#  'ABTO',
#  'ABTotal',
#  'ABUMRAD',
#  'ABUSA',
#  'ABUs',
#  'ABVA',
#  'ABVS',
#  'ABViewer',
#  'ABeam',
#  'ABfinity',
#  'ABgene',
#  'ABoR',
#  'ABody',
#  'ABySS',
#  'ACAAN',
#  'ACADM',
#  'ACAE',
#  'ACAMIS',
#  'ACARE',
#  'ACASA',
#  'ACASS',
#  'ACBAR',
#  'ACBB',
#  'ACBJ',
#  'ACBM',
#  'ACBs',
#  'ACCAHC',
#  'ACCCG',
#  'ACCCRN',
#  'ACCDE',
#  'ACCEO',
#  'ACCESSORIZE',
#  'ACCH',
#  'ACCIDENTALS',
#  'ACCIDENTLY',
#  'ACCOM',
#  'ACCOMMODATING',
#  'ACCOMODATIONS',
#  'ACCOMPLICE',
#  'ACCOUNTMY',
#  'ACCOUNTMy',
#  'ACCREDITATIONS',
#  'ACCRINGTON',
#  'ACCRUED',
#  'ACCUMULATE',
#  'ACCUMULATED',
#  'ACCUMULATIONS',
#  'ACCUMULATOR',
#  'ACCURA',
#  'ACCUS',
#  'ACCUSER',
#  'ACCUSING',
#  'ACCUs',
#  'ACCentral',
#  'ACCondition',
#  'ACDBE',
#  'ACDE',
#  'ACDL',
#  'ACDR',
#  'ACDX',
#  'ACELP',
#  'ACERA',
#  'ACETAMINOPHEN',
#  'ACETO',
#  'ACEVEDO',
#  'ACEX',
#  'ACEnet',
#  'ACFF',
#  'ACFJ',
#  'ACFO',
#  'ACFR',
#  'ACFRE',
#  'ACFTA',
#  'ACGB',
#  'ACGG',
#  'ACGI',
#  'ACGR',
#  'ACHAT',
#  'ACHETONS',
#  'ACHF',
#  'ACHIEVA',
#  'ACHIEVERS',
#  'ACHIEVES',
#  'ACHM',
#  'ACHRE',
#  'ACHs',
#  'ACIB',
#  'ACIDized',
#  'ACIE',
#  'ACIF',
#  'ACIG',
#  'ACIPHEX',
#  'ACIW',
#  'ACIs',
#  'ACJA',
#  'ACKLAM',
#  'ACKLEY',
#  'ACLEA',
#  'ACLJAbout',
#  'ACLJFacebookTwitterYouTubePinterestContact',
#  'ACLO',
#  'ACLY',
#  'ACMECS',
#  'ACMH',
#  'ACMR',
#  'ACMRS',
#  'ACNT',
#  'ACOAs',
#  'ACOC',
#  'ACOD',
#  'ACOFP',
#  'ACOK',
#  'ACOLYTE',
#  'ACOSOG',
#  'ACOTA',
#  'ACPB',
#  'ACPF',
#  'ACPN',
#  'ACPU',
#  'ACPW',
#  'ACQUITTED',
#  'ACRB',
#  'ACRR',
#  'ACRV',
#  'ACRYLITE',
#  'ACSMA',
#  'ACTAR',
#  'ACTAS',
#  'ACTAcreage',
#  'ACTEM',
#  'ACTEVA',
#  'ACTIA',
#  'ACTIN',
#  'ACTIONThe',
#  'ACTM',
#  'ACTOPLUS',
#  'ACTORSMovie',
#  'ACTORSee',
#  'ACTP',
#  'ACTRESSESMovie',
#  'ACTRecommendedHigh',
#  'ACTSI',
#  'ACTUALITY',
#  'ACTUARIAL',
#  'ACTUS',
#  'ACTWU',
#  'ACTYou',
#  'ACUE',
#  'ACULON',
#  'ACUP',
#  'ACUSHNET',
#  'ACUTA',
#  'ACUdraw',
#  'ACVD',
#  'ACWD',
#  'ACWIA',
#  'ACXM',
#  'ACar',
#  'AChEI',
#  'AChEIs',
#  'AChamfer',
#  'ACigarette',
#  'ACityDiscount',
#  'AClass',
#  'ACoC',
#  'ACoP',
#  'AColor',
#  'AComments',
#  'ACooper',
#  'ACostsFinancingInsuranceInterventionsSpecial',
#  'ACt',
#  'ACurrent',
#  'ACwAAAAADwAPAAcIjAD',
#  'ACwAAAAADwAPAAcIpgD',
#  'ADAGE',
#  'ADALINE',
#  'ADAMO',
#  'ADANA',
#  'ADANI',
#  'ADAPTATIONS',
#  'ADAPTING',
#  'ADCFP',
#  'ADCL',
#  'ADCOCK',
#  'ADCOLOR',
#  'ADCSRA',
#  'ADCT',
#  'ADDE',
#  'ADDIECAKES',
#  'ADDINGTON',
#  'ADDONS',
#  'ADDP',
#  'ADDRESSFront',
#  'ADDRESSMain',
#  'ADDRESSMyrtle',
#  'ADDRESSThe',
#  'ADDThe',
#  'ADDU',
#  'ADDer',
#  'ADEAR',
#  'ADEAWho',
#  'ADECA',
#  'ADED',
#  'ADEE',
#  'ADEK',
#  'ADELPHI',
#  'ADEOS',
#  'ADER',
#  'ADESH',
#  'ADFEST',
#  'ADFH',
#  'ADFL',
#  'ADGs',
#  'ADHE',
#  'ADHESION',
#  'ADHP',
#  'ADHR',
#  'ADHRB',
#  'ADHs',
#  'ADID',
#  'ADIES',
#  'ADIN',
#  'ADISA',
#  'ADISC',
#  'ADISORYPosted',
#  'ADITI',
#  'ADJOING',
#  'ADJOURN',
#  'ADJOURNED',
#  'ADJUDICATION',
#  'ADKAR',
#  'ADLC',
#  'ADLI',
#  'ADLT',
#  'ADMINISTERING',
#  'ADMIRALS',
#  'ADMIRATION',
#  'ADMIRED',
#  'ADMITTANCE',
#  'ADML',
#  'ADMRe',
#  'ADMSCs',
#  'ADOLESCENCE',
#  'ADOP',
#  'ADOPTABLE',
#  'ADOPTIVE',
#  'ADORA',
#  'ADORN',
#  'ADOs',
#  'ADPA',
#  'ADPSR',
#  'ADPlus',
#  'ADRESS',
#  'ADRIA',
#  'ADRN',
#  'ADRO',
#  'ADSD',
#  'ADSIEdit',
#  'ADSelfService',
#  'ADThe',
#  'ADUG',
#  'ADULTPosted',
#  'ADUS',
#  'ADVERBS',
#  'ADVERSARY',
#  'ADVERSITY',
#  'ADVERTISMENT',
#  'ADVI',
#  'ADVISEMENT',
#  'ADVISORIES',
#  'ADVISORIESUnited',
#  'ADVOC',
#  'ADWLauncher',
#  'ADWs',
#  'ADYAR',
#  'AData',
#  'ADate',
#  'ADateWithRosiePalms',
#  'ADay',
#  'ADelivery',
#  'ADnD',
#  'ADoctor',
#  'ADurability',
#  'AEAC',
#  'AEAD',
#  'AEAF',
#  'AEAT',
#  'AECCafe',
#  'AECG',
#  'AECM',
#  'AECOMAECOM',
#  'AECR',
#  'AEDA',
#  'AEDB',
#  'AEDI',
#  'AEDS',
#  'AEEA',
#  'AEEI',
#  'AEES',
#  'AEESP',
#  'AEEU',
#  'AEFLA',
#  'AEFs',
#  'AEGR',
#  'AEIC',
#  'AEIP',
#  'AEIdeas',
#  'AEMD',
#  'AEMET',
#  'AEMSA',
#  'AENEAS',
#  'AENM',
#  'AENY',
#  'AEOSTYLE',
#  'AEPI',
#  'AEPhi',
#  'AERL',
#  'AEROBICS',
#  'AEROPLANE',
#  'AEROSIL',
#  'AERP',
#  'AERZEN',
#  'AESE',
#  'AESL',
#  'AESSEAL',
#  'AETAS',
#  'AETF',
#  'AETHIEN',
#  'AETOS',
#  'AETR',
#  'AEUP',
#  'AEWC',
#  'AEZS',
#  'AEducation',
#  'AEgis',
#  'AElite',
#  'AEmail',
#  'AEneas',
#  'AEntertainment',
#  'AEons',
#  'AEterna',
#  'AEthelmearc',
#  'AEther',
#  'AEthnicity',
#  'AFAF',
#  'AFAQAll',
#  'AFBA',
#  'AFBC',
#  'AFBs',
#  'AFCARS',
#  'AFCCA',
#  'AFCEC',
#  'AFCM',
#  'AFDM',
#  'AFDW',
#  'AFEC',
#  'AFEE',
#  'AFEI',
#  'AFESIP',
#  'AFEW',
#  'AFEs',
#  'AFFIDAVITS',
#  'AFFLICTED',
#  'AFFT',
#  'AFFTC',
#  'AFGP',
#  'AFHE',
#  'AFHV',
#  'AFICIO',
#  'AFIF',
#  'AFIM',
#  'AFIRS',
#  'AFKing',
#  'AFLOAT',
#  'AFMBE',
#  'AFMI',
#  'AFNAF',
#  'AFOAF',
#  'AFOLU',
#  'AFOQT',
#  'AFOV',
#  'AFPAK',
#  'AFPF',
#  'AFPSRM',
#  'AFPTV',
#  'AFPhttp',
#  'AFRCC',
#  'AFREZZA',
#  'AFRIDI',
#  'AFRIKAN',
#  'AFRIQUE',
#  'AFROBEATRADIO',
#  'AFRP',
#  'AFRRI',
#  'AFSJ',
#  'AFSY',
#  'AFTAC',
#  'AFTD',
#  'AFTERBUZZ',
#  'AFTERSCHOOL',
#  'AFTERWARD',
#  'AFTH',
#  'AFTI',
#  'AFTM',
#  'AFTMontessori',
#  'AFTV',
#  'AFTVnews',
#  'AFWL',
#  'AFZAL',
#  'AFe',
#  'AFirst',
#  'AFlorida',
#  'AFort',
#  'AFrican',
#  'AGAD',
#  'AGAF',
#  'AGAI',
#  'AGAM',
#  'AGAMA',
#  'AGAMOUS',
#  'AGAS',
#  'AGAdvertising',
#  'AGBAZARA',
#  'AGCT',
#  'AGDI',
#  'AGEM',
#  'AGENCIA',
#  'AGFI',
#  'AGFPRO',
#  'AGFS',
#  'AGFUND',
#  'AGGRESSIVELY',
#  'AGGRESSOR',
#  'AGGRO',
#  'AGHD',
#  'AGHE',
#  'AGII',
#  'AGIN',
#  'AGIOS',
#  'AGIT',
#  'AGITATION',
#  'AGJ',
#  'AGNA',
#  'AGNET',
#  'AGNIVEER',
#  'AGNR',
#  'AGNUS',
#  'AGOL',
#  'AGONIST',
#  'AGOSTINI',
#  'AGOSTO',
#  'AGOURA',
#  'AGPC',
#  'AGRAVIS',
#  'AGRC',
#  'AGREEMENTBy',
#  'AGRF',
#  'AGRIBUSINESS',
#  'AGRICOLE',
#  'AGRM',
#  'AGRU',
#  'AGRs',
#  'AGSE',
#  'AGSS',
#  'AGST',
#  'AGTL',
#  'AGUE',
#  'AGUERO',
#  'AGUSTA',
#  'AGWers',
#  'AGWs',
#  'AGYA',
#  'AGZ',
#  'AGain',
#  'AGree',
#  'AHAHAH',
#  'AHAHAHAHAHAHA',
#  'AHAN',
#  'AHANA',
#  'AHAT',
#  'AHBs',
#  'AHCP',
#  'AHCS',
#  'AHCT',
#  'AHDN',
#  'AHEA',
#  'AHEI',
#  'AHHAA',
#  'AHHHHHHHHHHHH',
#  'AHHHHHHHHHHHHH',
#  'AHIA',
#  'AHIF',
#  'AHIMSA',
#  'AHIMT',
#  'AHIS',
#  'AHLC',
#  'AHLS',
#  'AHLers',
#  'AHMAC',
#  'AHML',
#  'AHNS',
#  'AHORA',
#  'AHPP',
#  'AHRF',
#  'AHRN',
#  'AHRP',
#  'AHRR',
#  'AHSG',
#  'AHSGR',
#  'AHSL',
#  'AHSNs',
#  'AHTA',
#  'AHTEC',
#  'AHTN',
#  'AHURI',
#  'AHVA',
#  'AHWs',
#  'AHY',
#  'AHe',
#  'AHepatitis',
#  'AHmazing',
#  'AHouston',
#  'AHr',
#  'AIABaltimore',
#  'AIADA',
#  'AIAP',
#  'AIBI',
#  'AIBTM',
#  'AICCU',
#  'AICDA',
#  'AICGS',
#  'AICH',
#  'AICRP',
#  'AIDAprima',
#  'AIDB',
#  'AIDF',
#  'AIDG',
#  'AIDL',
#  'AIDR',
#  'AIDSMEDS',
#  'AIDT',
#  'AIEP',
#  'AIES',
#  'AIFI',
#  'AIGO',
#  'AIGP',
#  'AIHM',
#  'AIHS',
#  'AIICO',
#  'AIJA',
#  'AIKI',
#  'AIKMAN',
#  'AIKS',
#  'AILC',
#  'AILF',
#  'AILS',
#  'AIMES',
#  'AIMEX',
#  'AIMSS',
#  'AIMSweb',
#  'AINES',
#  'AINP',
#  'AINSLIE',
#  'AIOM',
#  'AIOP',
#  'AIPF',
#  'AIPIA',
#  'AIPN',
#  'AIPO',
#  'AIPR',
#  'AIPT',
#  'AIRASIA',
#  'AIRB',
#  'AIRBAGS',
#  'AIRBENDER',
#  'AIRCAP',
#  'AIREX',
#  'AIRFA',
#  'AIRGUN',
#  'AIRI',
#  'AIRLIE',
#  'AIRMEN',
#  'AIRP',
#  'AIRSAR',
#  'AIRSCARF',
#  'AIRSHIP',
#  'AIRSPACE',
#  'AIRSTREAM',
#  'AIRTIME',
#  'AIRWAVES',
#  'AIRbnb',
#  'AIRheads',
#  'AISLINNFour',
#  'AISM',
#  'AISO',
#  'AISs',
#  'AITB',
#  'AITE',
#  'AITH',
#  'AITs',
#  'AIUK',
#  'AIVA',
#  'AIVAS',
#  'AIVL',
#  'AIWS',
#  'AIWW',
#  'AId',
#  'AIncident',
#  'AIrport',
#  'AJAMI',
#  'AJAR',
#  'AJAS',
#  'AJCA',
#  'AJCN',
#  'AJCommittee',
#  'AJDC',
#  'AJEnglish',
#  'AJHG',
#  'AJIL',
#  'AJLI',
#  'AJMAPreparación',
#  'AJNI',
#  'AJOL',
#  'AJPA',
#  'AJPH',
#  'AJPS',
#  'AJV',
#  'AJVD',
#  'AJWM',
#  'AJust',
#  'AJxtcman',
#  'AKAR',
#  'AKASHA',
#  'AKATSUKI',
#  'AKCGY',
#  'AKCHO',
#  'AKERECO',
#  'AKERMAN',
#  'AKES',
#  'AKHTAR',
#  'AKID',
#  'AKIM',
#  'AKIS',
#  'AKKApr',
#  'AKMU',
#  'AKMs',
#  'AKOO',
#  'AKOT',
#  'AKPD',
#  'AKQ',
#  'AKRAM',
#  'AKRNA',
#  'AKRSP',
#  'AKSHAY',
#  'AKSHAYA',
#  'AKTI',
#  'AKTIV',
#  'AKUH',
#  'AKVA',
#  'AKY',
#  'AKnews',
#  'AKyemeni',
#  'ALABANG',
#  'ALABASTER',
#  'ALAConnect',
#  'ALAMANCE',
#  'ALAMOGORDO',
#  'ALAMPUR',
#  'ALANIS',
#  'ALARIC',
#  'ALARMED',
#  'ALASA',
#  'ALAW',
#  'ALAs',
#  'ALAvailable',
#  'ALBAN',
#  'ALBD',
#  'ALBEDO',
#  'ALBERGOTTI',
#  'ALBERS',
#  'ALBI',
#  'ALBO',
#  'ALBURY',
#  'ALBW',
#  'ALBachelor',
#  'ALBs',
#  'ALCI',
#  'ALCMs',
#  'ALCOM',
#  'ALCOR',
#  'ALCOTT',
#  'ALDEFLUOR',
#  'ALDERSON',
#  'ALDHs',
#  'ALDOA',
#  'ALDOUS',
#  'ALDUB',
#  'ALEJANDRA',
#  'ALEN',
#  'ALENA',
#  'ALEP',
#  'ALERTSStay',
#  'ALEUTIAN',
#  'ALEXEY',
#  'ALEXI',
#  'ALFRETON',
#  'ALGEBRAIC',
#  'ALHAMDULILLAH',
#  'ALHFAM',
#  'ALHI',
#  'ALHeating',
#  'ALIASES',
#  'ALIBEY',
#  'ALIC',
#  'ALIENATION',
#  'ALIENATORS',
#  'ALIENWARE',
#  'ALIGNING',
#  'ALIMCO',
#  'ALIMONY',
#  'ALISHA',
#  'ALISS',
#  'ALIV',
#  'ALKA',
#  'ALKAbells',
#  'ALKs',
#  'ALLEA',
#  'ALLEGAN',
#  'ALLEGIANT',
#  'ALLEGORY',
#  'ALLENDALE',
#  'ALLENDE',
#  'ALLERGENS',
#  'ALLEYGOLDEN',
#  'ALLEZ',
#  'ALLIANZ',
#  'ALLIGATORS',
#  'ALLLLLLLL',
#  'ALLOCATIONS',
#  'ALLOWABLE',
#  'ALLPage',
#  'ALLROAD',
#  'ALLRelated',
#  'ALLReviews',
#  'ALLSAINTS',
#  'ALLSPORT',
#  'ALLSTON',
#  'ALLT',
#  'ALLU',
#  'ALLURING',
#  'ALMC',
#  'ALMI',
#  'ALMOs',
#  'ALMP',
#  'ALMPs',
#  'ALMT',
#  'ALMs',
#  'ALOC',
#  'ALOHAnet',
#  'ALOK',
#  'ALOP',
#  'ALOPECIA',
#  'ALORICA',
#  'ALPAC',
#  'ALPACAS',
#  'ALPHAS',
#  'ALPHONSE',
#  'ALPHONSO',
#  'ALPLM',
#  'ALPN',
#  'ALRM',
#  'ALRV',
#  'ALSACE',
#  'ALSI',
#  'ALSK',
#  'ALSM',
#  'ALSS',
#  'ALST',
#  'ALSTYNE',
#  'ALSince',
#  'ALSscan',
#  'ALTAFF',
#  'ALTAVILLA',
#  'ALTERA',
#  'ALTERNA',
#  'ALTERNATIVELY',
#  'ALTERS',
#  'ALTIMARI',
#  'ALTIS',
#  'ALTRINCHAM',
#  'ALTV',
#  'ALUA',
#  'ALUMNUS',
#  'ALVIS',
#  'ALWAYs',
#  'ALWS',
#  'ALWebsite',
#  'ALXA',
#  'ALYN',
#  'ALYSON',
#  ...]

# %%
print([s for s in data if (s.startswith('Mother'))][:10])
# Out:
# ['MotherA', 'MotherCustomize', 'MotherCustomized', 'MotherCute', 'MotherDaughterBookReviews', 'MotherF', 'MotherFucker', 'MotherGod', 'MotherI', 'MotherPersonalize']
