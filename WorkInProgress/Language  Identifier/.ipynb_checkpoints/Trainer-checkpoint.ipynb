# %%
import re
import wikipedia as wiki
from unidecode import unidecode
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

# %%
max_letters = 12
language_tags = {

                'en':['actor', 'alcohol', 'cheque', 'cancer', 'chocolate', 'debate', 'hobby', 'melon', 'propaganda',
                      'religion', 'violin', 'england', 'MediaWiki'],

                'si':["ශ්‍රී දළදා මාළිගාව",  "දියවඩන නිලමේ", "මහනුවර", "මාතලේ පරිපාලන දිස්ත්‍රික්කය", "ලංකා දිවයින","සංස්කෘතිය",
                      "න්‍යෂ්ටික අවි","තිරසාර සංවර්ධනය","කාන්තාව හා සංවර්ධනය","ආර්ථික සංවර්ධනය","මුල් ළමාවියේ සංවර්ධනය",
                     "ඵලදායී පාසල","රසායනික කර්මාන්ත","පළමුවන විමලධර්මසූරිය රජ","දළදා වහන්සේ","දියවඩන නිලමේ","මහනුවර","සමාජ වෙළඳ පොළ ආර්ථිකය",
                     "නාලන්දා විශ්වවිද්‍යාලය","CIA ගැන අභ්‍යන්තර සමාලෝචනය","CPU උපදෙස් මට්ටමේ සමාන්තරතාවය","ඔලිම්පික්","ශ්‍රී ලංකාවේ 14වන පාර්ලිමේන්තුව","හෘදය","උසස් පෙළ දේශපාලන විද්‍යාව",
                     "චීන ඉතිහාසය","ශ්‍රී ලංකාවේ 9වන පාර්ලිමේන්තුව","යුදෙවු ආගම","කොරියාවේ ඉතිහාසය","ජොසොන්","අක්නාටන්","ජන සන්නිවේදනය",
                     "ටයිටැනික් (නෞකාව)","සීගිරියේ සංස්කෘතික වටිනාකම්","කුමාරතුංග කැබිනට් මණ්ඩලය","චෝළ රාජවංශය","ධම්‌මහදයවිභඞ්‌ගො","බොරතෙල්","ඇඩොල්ෆ් හිට්ලර්",
                     "එක් දින ජාත්‍යන්තර ක්‍රිකට් වාර්තා ලැයිස්තුව","ශ්‍රී ලංකා යුද්ධ හමුදාව","ඉන්දු-යුරෝපීය භාෂා පවුල","ශ්‍රී ලංකාවේ 13වන පාර්ලිමේන්තුව",
                     "ගනේෂ","ශ්‍රී ලංකාවේ 12වන පාර්ලිමේන්තුව","ශ්‍රී ලංකාවේ 10වන පාර්ලිමේන්තුව","හන්ටිංටන්ගේ රෝගය","බියුටි ඇන්ඩ් ද බීස්ට් (2017 චිත්‍රපටය)"]

                 }

# %%
def generate_dictionary(tag, max_word_length):
    wiki.set_lang(tag)
    for topic in language_tags[tag]:
        # Scrap html content of webpage
        page = wiki.WikipediaPage(topic)
        #scrap plain text from page
        content = page.content
        #Unidecode the content
        content = unidecode(content)
        lst = process(content, max_word_length)
    print(tag+" word count: "+str(len(lst)))
    return lst

# %%
def process(page_content, max_word_length):
    #get only word with regular expression
    words = re.sub(r'[^a-zA-Z ]', '', page_content)
    lower = words.lower()
    word_list = lower.split()
    short_words = []
    #check the word length with given max_word_length
    for word in word_list:
        if len(word) <= max_word_length:
            short_words.append(word)
    return short_words

# %%
def convert_dic_to_vector(dic, max_word_length):
    new_list = []
    for word in dic:
        #output vector for one word
        vec = ''
        n = len(word)
        #convert charactor to one-hot-vector
        for i in range(n):
            #iterate each letter in word
            current_letter = word[i]
            #get the charactor position in a-z order
            ind = ord(current_letter)-97
            #Create one hot vector
            placeholder = (str(0)*ind) + str(1) + str(0)*(25-ind)
            #add char vector to word vector
            vec = vec + placeholder
        #create all waords as 12 length
        if n < max_word_length:
            excess = max_word_length-n
            vec = vec +str(0)*26*excess
        new_list.append(vec)
    return new_list

# %%
def create_output_vector(tag_index, number_of_languages):
    #Create tags for outputs
    out = str(0)*tag_index + str(1) + str(0)*(number_of_languages-1-tag_index)
    return out

# %%
#vector words list
word_data = []
#output vectors list
language_data = []
#word list
master_dic = []

#to keep the language count
count = 0

for tag in language_tags.keys():
    print('generating dictionary for ' + tag)
    #genarate dictionary for each language
    dic = generate_dictionary(tag, max_letters)
    #create main dictionary with all langs words
    for word in dic:
        master_dic.append(word)
    #vectorize the words in language dic
    vct = convert_dic_to_vector(dic, max_letters)
    #add vectorized word data in to word_data array
    for vector in vct:
        word_data.append(vector)
    #create output vectors
    output_vct = create_output_vector(count, len(language_tags))
    #add output vector data to language_data array
    for i in range(len(vct)):
        language_data.append(output_vct)
    count += 1
# Out:
# generating dictionary for en
# en word count 5901
# generating dictionary for si
# si word count 5408

# %%
arr = []

#create [word,word_vec,lang_vec] array and append in to arr
for i in range(len(word_data)):
    entry = []
    entry.append(master_dic[i])
    for digit in language_data[i]:
        entry.append(float(digit))
    for digit in word_data[i]:
        entry.append(float(digit))
    arr.append(entry)

#create dataframe with arr
arr = np.array(arr)
print(len(arr[1]))
np.save('arr.npy', arr)
df=pd.DataFrame(arr)
df.to_csv('data.csv')
print("Done")
print(type(arr))
# Out:
# 315
# Done
# <class 'numpy.ndarray'>

# %%
data = arr

inputs = data[:, 1+len(language_tags):]
labels = data[:, 1:1+len(language_tags)]

x_train, x_test, y_train, y_test = train_test_split(inputs, labels, test_size=0.15)

print(x_test.shape)
print(y_test.shape)
print(x_train.shape)
print(y_train.shape)
# Out:
# (1697, 312)
# (1697, 2)
# (9612, 312)
# (9612, 2)

# %%
network = Sequential()
network.add(Dense(200, input_dim=26*max_letters, activation='sigmoid'))
network.add(Dense(150, activation='sigmoid'))
network.add(Dense(100, activation='sigmoid'))
network.add(Dense(100, activation='sigmoid'))
network.add(Dense(len(language_tags), activation='softmax'))

network.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\thili\Anaconda3\envs\fyp\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
filepath = "weights.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
tboard = TensorBoard(log_dir='./logs', write_graph=True, write_images=True)
callbacks_list = [checkpoint, tboard]

network.fit(x_train, y_train, epochs=100, batch_size=1000, validation_data=(x_test, y_test), callbacks=callbacks_list)
# Out:
# WARNING:tensorflow:From C:\Users\thili\Anaconda3\envs\fyp\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 9612 samples, validate on 1697 samples
# Epoch 1/100
# 9612/9612 [==============================] - 4s 371us/step - loss: 0.2974 - acc: 0.4926 - val_loss: 0.2702 - val_acc: 0.5398
#
# Epoch 00001: val_acc improved from -inf to 0.53978, saving model to weights.hdf5
# Epoch 2/100
# 9612/9612 [==============================] - 3s 314us/step - loss: 0.2624 - acc: 0.5147 - val_loss: 0.2550 - val_acc: 0.4602
#
# Epoch 00002: val_acc did not improve from 0.53978
# Epoch 3/100
# 9612/9612 [==============================] - 3s 312us/step - loss: 0.2530 - acc: 0.4870 - val_loss: 0.2481 - val_acc: 0.5398
#
# Epoch 00003: val_acc did not improve from 0.53978
# Epoch 4/100
# 9612/9612 [==============================] - 3s 314us/step - loss: 0.2503 - acc: 0.5186 - val_loss: 0.2478 - val_acc: 0.5398
#
# Epoch 00004: val_acc did not improve from 0.53978
# Epoch 5/100
# 9612/9612 [==============================] - 3s 325us/step - loss: 0.2498 - acc: 0.4891 - val_loss: 0.2483 - val_acc: 0.5398
#
# Epoch 00005: val_acc did not improve from 0.53978
# Epoch 6/100
# 9612/9612 [==============================] - 3s 319us/step - loss: 0.2488 - acc: 0.5186 - val_loss: 0.2472 - val_acc: 0.5398
#
# Epoch 00006: val_acc did not improve from 0.53978
# Epoch 7/100
# 9612/9612 [==============================] - 3s 312us/step - loss: 0.2482 - acc: 0.5315 - val_loss: 0.2469 - val_acc: 0.5398
#
# Epoch 00007: val_acc did not improve from 0.53978
# Epoch 8/100
# 9612/9612 [==============================] - 3s 313us/step - loss: 0.2472 - acc: 0.5186 - val_loss: 0.2453 - val_acc: 0.5398
#
# Epoch 00008: val_acc did not improve from 0.53978
# Epoch 9/100
# 9612/9612 [==============================] - 3s 328us/step - loss: 0.2455 - acc: 0.5828 - val_loss: 0.2426 - val_acc: 0.5445
#
# Epoch 00009: val_acc improved from 0.53978 to 0.54449, saving model to weights.hdf5
# Epoch 10/100
# 9612/9612 [==============================] - 3s 324us/step - loss: 0.2420 - acc: 0.5737 - val_loss: 0.2380 - val_acc: 0.8173
#
# Epoch 00010: val_acc improved from 0.54449 to 0.81732, saving model to weights.hdf5
# Epoch 11/100
# 9612/9612 [==============================] - 3s 321us/step - loss: 0.2339 - acc: 0.7593 - val_loss: 0.2230 - val_acc: 0.7466
#
# Epoch 00011: val_acc did not improve from 0.81732
# Epoch 12/100
# 9612/9612 [==============================] - 3s 327us/step - loss: 0.2150 - acc: 0.7802 - val_loss: 0.1933 - val_acc: 0.7714
#
# Epoch 00012: val_acc did not improve from 0.81732
# Epoch 13/100
# 9612/9612 [==============================] - 3s 319us/step - loss: 0.1800 - acc: 0.7937 - val_loss: 0.1513 - val_acc: 0.8197
#
# Epoch 00013: val_acc improved from 0.81732 to 0.81968, saving model to weights.hdf5
# Epoch 14/100
# 9612/9612 [==============================] - 3s 326us/step - loss: 0.1445 - acc: 0.8142 - val_loss: 0.1247 - val_acc: 0.8403
#
# Epoch 00014: val_acc improved from 0.81968 to 0.84031, saving model to weights.hdf5
# Epoch 15/100
# 9612/9612 [==============================] - 3s 321us/step - loss: 0.1252 - acc: 0.8347 - val_loss: 0.1123 - val_acc: 0.8521
#
# Epoch 00015: val_acc improved from 0.84031 to 0.85209, saving model to weights.hdf5
# Epoch 16/100
# 9612/9612 [==============================] - 3s 345us/step - loss: 0.1147 - acc: 0.8546 - val_loss: 0.1053 - val_acc: 0.8603
#
# Epoch 00016: val_acc improved from 0.85209 to 0.86034, saving model to weights.hdf5
# Epoch 17/100
# 9612/9612 [==============================] - 3s 363us/step - loss: 0.1079 - acc: 0.8653 - val_loss: 0.1008 - val_acc: 0.8774
#
# Epoch 00017: val_acc improved from 0.86034 to 0.87743, saving model to weights.hdf5
# Epoch 18/100
# 9612/9612 [==============================] - 3s 336us/step - loss: 0.1029 - acc: 0.8720 - val_loss: 0.0983 - val_acc: 0.8810
#
# Epoch 00018: val_acc improved from 0.87743 to 0.88097, saving model to weights.hdf5
# Epoch 19/100
# 9612/9612 [==============================] - 3s 344us/step - loss: 0.1007 - acc: 0.8767 - val_loss: 0.0954 - val_acc: 0.8827
#
# Epoch 00019: val_acc improved from 0.88097 to 0.88273, saving model to weights.hdf5
# Epoch 20/100
# 9612/9612 [==============================] - 3s 323us/step - loss: 0.0974 - acc: 0.8818 - val_loss: 0.0940 - val_acc: 0.8816
#
# Epoch 00020: val_acc did not improve from 0.88273
# Epoch 21/100
# 9612/9612 [==============================] - 3s 320us/step - loss: 0.0952 - acc: 0.8839 - val_loss: 0.0917 - val_acc: 0.8869
#
# Epoch 00021: val_acc improved from 0.88273 to 0.88686, saving model to weights.hdf5
# Epoch 22/100
# 9612/9612 [==============================] - 3s 316us/step - loss: 0.0931 - acc: 0.8868 - val_loss: 0.0902 - val_acc: 0.8851
#
# Epoch 00022: val_acc did not improve from 0.88686
# Epoch 23/100
# 9612/9612 [==============================] - 3s 323us/step - loss: 0.0916 - acc: 0.8889 - val_loss: 0.0892 - val_acc: 0.8904
#
# Epoch 00023: val_acc improved from 0.88686 to 0.89039, saving model to weights.hdf5
# Epoch 24/100
# 9612/9612 [==============================] - 3s 325us/step - loss: 0.0904 - acc: 0.8925 - val_loss: 0.0882 - val_acc: 0.8892
#
# Epoch 00024: val_acc did not improve from 0.89039
# Epoch 25/100
# 9612/9612 [==============================] - 3s 318us/step - loss: 0.0899 - acc: 0.8948 - val_loss: 0.0885 - val_acc: 0.8922
#
# Epoch 00025: val_acc improved from 0.89039 to 0.89216, saving model to weights.hdf5
# Epoch 26/100
# 9612/9612 [==============================] - 3s 326us/step - loss: 0.0900 - acc: 0.8939 - val_loss: 0.0890 - val_acc: 0.8951
#
# Epoch 00026: val_acc improved from 0.89216 to 0.89511, saving model to weights.hdf5
# Epoch 27/100
# 9612/9612 [==============================] - 3s 337us/step - loss: 0.0889 - acc: 0.8963 - val_loss: 0.0871 - val_acc: 0.8957
#
# Epoch 00027: val_acc improved from 0.89511 to 0.89570, saving model to weights.hdf5
# Epoch 28/100
# 9612/9612 [==============================] - 3s 327us/step - loss: 0.0884 - acc: 0.8957 - val_loss: 0.0862 - val_acc: 0.8969
#
# Epoch 00028: val_acc improved from 0.89570 to 0.89688, saving model to weights.hdf5
# Epoch 29/100
# 9612/9612 [==============================] - 3s 320us/step - loss: 0.0873 - acc: 0.8996 - val_loss: 0.0853 - val_acc: 0.8981
#
# Epoch 00029: val_acc improved from 0.89688 to 0.89806, saving model to weights.hdf5
# Epoch 30/100
# 9612/9612 [==============================] - 3s 329us/step - loss: 0.0862 - acc: 0.8992 - val_loss: 0.0850 - val_acc: 0.8981
#
# Epoch 00030: val_acc did not improve from 0.89806
# Epoch 31/100
# 9612/9612 [==============================] - 3s 322us/step - loss: 0.0851 - acc: 0.9003 - val_loss: 0.0848 - val_acc: 0.8998
#
# Epoch 00031: val_acc improved from 0.89806 to 0.89982, saving model to weights.hdf5
# Epoch 32/100
# 9612/9612 [==============================] - 3s 325us/step - loss: 0.0845 - acc: 0.9020 - val_loss: 0.0845 - val_acc: 0.9016
#
# Epoch 00032: val_acc improved from 0.89982 to 0.90159, saving model to weights.hdf5
# Epoch 33/100
# 9612/9612 [==============================] - 3s 331us/step - loss: 0.0839 - acc: 0.9029 - val_loss: 0.0844 - val_acc: 0.9016
#
# Epoch 00033: val_acc did not improve from 0.90159
# Epoch 34/100
# 9612/9612 [==============================] - 3s 353us/step - loss: 0.0841 - acc: 0.9038 - val_loss: 0.0837 - val_acc: 0.9016
#
# Epoch 00034: val_acc did not improve from 0.90159
# Epoch 35/100
# 9612/9612 [==============================] - 3s 325us/step - loss: 0.0827 - acc: 0.9069 - val_loss: 0.0838 - val_acc: 0.9028
#
# Epoch 00035: val_acc improved from 0.90159 to 0.90277, saving model to weights.hdf5
# Epoch 36/100
# 9612/9612 [==============================] - 3s 330us/step - loss: 0.0833 - acc: 0.9071 - val_loss: 0.0832 - val_acc: 0.9022
#
# Epoch 00036: val_acc did not improve from 0.90277
# Epoch 37/100
# 9612/9612 [==============================] - 3s 325us/step - loss: 0.0825 - acc: 0.9082 - val_loss: 0.0835 - val_acc: 0.9039
#
# Epoch 00037: val_acc improved from 0.90277 to 0.90395, saving model to weights.hdf5
# Epoch 38/100
# 9612/9612 [==============================] - 3s 331us/step - loss: 0.0817 - acc: 0.9080 - val_loss: 0.0832 - val_acc: 0.9034
#
# Epoch 00038: val_acc did not improve from 0.90395
# Epoch 39/100
# 9612/9612 [==============================] - 3s 329us/step - loss: 0.0811 - acc: 0.9083 - val_loss: 0.0827 - val_acc: 0.9022
#
# Epoch 00039: val_acc did not improve from 0.90395
# Epoch 40/100
# 9612/9612 [==============================] - 3s 327us/step - loss: 0.0805 - acc: 0.9101 - val_loss: 0.0854 - val_acc: 0.9069
#
# Epoch 00040: val_acc improved from 0.90395 to 0.90689, saving model to weights.hdf5
# Epoch 41/100
# 9612/9612 [==============================] - 3s 341us/step - loss: 0.0816 - acc: 0.9110 - val_loss: 0.0841 - val_acc: 0.9063
#
# Epoch 00041: val_acc did not improve from 0.90689
# Epoch 42/100
# 9612/9612 [==============================] - 3s 322us/step - loss: 0.0815 - acc: 0.9095 - val_loss: 0.0827 - val_acc: 0.9016
#
# Epoch 00042: val_acc did not improve from 0.90689
# Epoch 43/100
# 9612/9612 [==============================] - 3s 324us/step - loss: 0.0806 - acc: 0.9096 - val_loss: 0.0827 - val_acc: 0.9057
#
# Epoch 00043: val_acc did not improve from 0.90689
# Epoch 44/100
# 9612/9612 [==============================] - 3s 326us/step - loss: 0.0792 - acc: 0.9133 - val_loss: 0.0821 - val_acc: 0.9028
#
# Epoch 00044: val_acc did not improve from 0.90689
# Epoch 45/100
# 9612/9612 [==============================] - 3s 334us/step - loss: 0.0788 - acc: 0.9127 - val_loss: 0.0817 - val_acc: 0.9045
#
# Epoch 00045: val_acc did not improve from 0.90689
# Epoch 46/100
# 9612/9612 [==============================] - 3s 320us/step - loss: 0.0785 - acc: 0.9149 - val_loss: 0.0823 - val_acc: 0.9069
#
# Epoch 00046: val_acc improved from 0.90689 to 0.90689, saving model to weights.hdf5
# Epoch 47/100
# 9612/9612 [==============================] - 3s 330us/step - loss: 0.0788 - acc: 0.9134 - val_loss: 0.0822 - val_acc: 0.9069
#
# Epoch 00047: val_acc did not improve from 0.90689
# Epoch 48/100
# 9612/9612 [==============================] - 3s 321us/step - loss: 0.0782 - acc: 0.9147 - val_loss: 0.0816 - val_acc: 0.9057
#
# Epoch 00048: val_acc did not improve from 0.90689
# Epoch 49/100
# 9612/9612 [==============================] - 3s 328us/step - loss: 0.0779 - acc: 0.9153 - val_loss: 0.0826 - val_acc: 0.9069
#
# Epoch 00049: val_acc did not improve from 0.90689
# Epoch 50/100
# 9612/9612 [==============================] - 3s 329us/step - loss: 0.0784 - acc: 0.9139 - val_loss: 0.0813 - val_acc: 0.9045
#
# Epoch 00050: val_acc did not improve from 0.90689
# Epoch 51/100
# 9612/9612 [==============================] - 3s 328us/step - loss: 0.0772 - acc: 0.9165 - val_loss: 0.0815 - val_acc: 0.9087
#
# Epoch 00051: val_acc improved from 0.90689 to 0.90866, saving model to weights.hdf5
# Epoch 52/100
# 9612/9612 [==============================] - 3s 322us/step - loss: 0.0773 - acc: 0.9155 - val_loss: 0.0813 - val_acc: 0.9081
#
# Epoch 00052: val_acc did not improve from 0.90866
# Epoch 53/100
# 9612/9612 [==============================] - 3s 326us/step - loss: 0.0766 - acc: 0.9172 - val_loss: 0.0812 - val_acc: 0.9081
#
# Epoch 00053: val_acc did not improve from 0.90866
# Epoch 54/100
# 9612/9612 [==============================] - 3s 329us/step - loss: 0.0764 - acc: 0.9183 - val_loss: 0.0820 - val_acc: 0.9087
#
# Epoch 00054: val_acc did not improve from 0.90866
# Epoch 55/100
# 9612/9612 [==============================] - 3s 337us/step - loss: 0.0764 - acc: 0.9184 - val_loss: 0.0815 - val_acc: 0.9075
#
# Epoch 00055: val_acc did not improve from 0.90866
# Epoch 56/100
# 9612/9612 [==============================] - 3s 332us/step - loss: 0.0763 - acc: 0.9176 - val_loss: 0.0806 - val_acc: 0.9093
#
# Epoch 00056: val_acc improved from 0.90866 to 0.90925, saving model to weights.hdf5
# Epoch 57/100
# 9612/9612 [==============================] - 3s 333us/step - loss: 0.0750 - acc: 0.9212 - val_loss: 0.0805 - val_acc: 0.9122
#
# Epoch 00057: val_acc improved from 0.90925 to 0.91220, saving model to weights.hdf5
# Epoch 58/100
# 9612/9612 [==============================] - 3s 331us/step - loss: 0.0748 - acc: 0.9207 - val_loss: 0.0807 - val_acc: 0.9087
#
# Epoch 00058: val_acc did not improve from 0.91220
# Epoch 59/100
# 9612/9612 [==============================] - 3s 320us/step - loss: 0.0744 - acc: 0.9208 - val_loss: 0.0810 - val_acc: 0.9051
#
# Epoch 00059: val_acc did not improve from 0.91220
# Epoch 60/100
# 9612/9612 [==============================] - 3s 339us/step - loss: 0.0743 - acc: 0.9218 - val_loss: 0.0803 - val_acc: 0.9151
#
# Epoch 00060: val_acc improved from 0.91220 to 0.91514, saving model to weights.hdf5
# Epoch 61/100
# 9612/9612 [==============================] - 3s 348us/step - loss: 0.0738 - acc: 0.9230 - val_loss: 0.0804 - val_acc: 0.9134
#
# Epoch 00061: val_acc did not improve from 0.91514
# Epoch 62/100
# 9612/9612 [==============================] - 3s 339us/step - loss: 0.0735 - acc: 0.9221 - val_loss: 0.0802 - val_acc: 0.9151
#
# Epoch 00062: val_acc did not improve from 0.91514
# Epoch 63/100
# 9612/9612 [==============================] - 3s 323us/step - loss: 0.0733 - acc: 0.9241 - val_loss: 0.0811 - val_acc: 0.9063
#
# Epoch 00063: val_acc did not improve from 0.91514
# Epoch 64/100
# 9612/9612 [==============================] - 3s 323us/step - loss: 0.0732 - acc: 0.9229 - val_loss: 0.0801 - val_acc: 0.9075
#
# Epoch 00064: val_acc did not improve from 0.91514
# Epoch 65/100
# 9612/9612 [==============================] - 3s 328us/step - loss: 0.0726 - acc: 0.9251 - val_loss: 0.0798 - val_acc: 0.9146
#
# Epoch 00065: val_acc did not improve from 0.91514
# Epoch 66/100
# 9612/9612 [==============================] - 3s 329us/step - loss: 0.0724 - acc: 0.9255 - val_loss: 0.0795 - val_acc: 0.9163
#
# Epoch 00066: val_acc improved from 0.91514 to 0.91632, saving model to weights.hdf5
# Epoch 67/100
# 9612/9612 [==============================] - 3s 346us/step - loss: 0.0722 - acc: 0.9264 - val_loss: 0.0797 - val_acc: 0.9169
#
# Epoch 00067: val_acc improved from 0.91632 to 0.91691, saving model to weights.hdf5
# Epoch 68/100
# 9612/9612 [==============================] - 3s 333us/step - loss: 0.0720 - acc: 0.9261 - val_loss: 0.0792 - val_acc: 0.9146
#
# Epoch 00068: val_acc did not improve from 0.91691
# Epoch 69/100
# 9612/9612 [==============================] - 3s 327us/step - loss: 0.0719 - acc: 0.9255 - val_loss: 0.0794 - val_acc: 0.9128
#
# Epoch 00069: val_acc did not improve from 0.91691
# Epoch 70/100
# 9612/9612 [==============================] - 3s 333us/step - loss: 0.0716 - acc: 0.9264 - val_loss: 0.0791 - val_acc: 0.9163
#
# Epoch 00070: val_acc did not improve from 0.91691
# Epoch 71/100
# 9612/9612 [==============================] - 3s 324us/step - loss: 0.0726 - acc: 0.9254 - val_loss: 0.0791 - val_acc: 0.9163
#
# Epoch 00071: val_acc did not improve from 0.91691
# Epoch 72/100
# 9612/9612 [==============================] - 3s 328us/step - loss: 0.0716 - acc: 0.9257 - val_loss: 0.0790 - val_acc: 0.9151
#
# Epoch 00072: val_acc did not improve from 0.91691
# Epoch 73/100
# 9612/9612 [==============================] - 3s 327us/step - loss: 0.0710 - acc: 0.9254 - val_loss: 0.0789 - val_acc: 0.9163
#
# Epoch 00073: val_acc did not improve from 0.91691
# Epoch 74/100
# 9612/9612 [==============================] - 3s 328us/step - loss: 0.0708 - acc: 0.9267 - val_loss: 0.0782 - val_acc: 0.9181
#
# Epoch 00074: val_acc improved from 0.91691 to 0.91809, saving model to weights.hdf5
# Epoch 75/100
# 9612/9612 [==============================] - 3s 331us/step - loss: 0.0707 - acc: 0.9272 - val_loss: 0.0784 - val_acc: 0.9163
#
# Epoch 00075: val_acc did not improve from 0.91809
# Epoch 76/100
# 9612/9612 [==============================] - 3s 334us/step - loss: 0.0709 - acc: 0.9281 - val_loss: 0.0787 - val_acc: 0.9187
#
# Epoch 00076: val_acc improved from 0.91809 to 0.91868, saving model to weights.hdf5
# Epoch 77/100
# 9612/9612 [==============================] - 3s 331us/step - loss: 0.0711 - acc: 0.9257 - val_loss: 0.0795 - val_acc: 0.9169
#
# Epoch 00077: val_acc did not improve from 0.91868
# Epoch 78/100
# 9612/9612 [==============================] - 3s 334us/step - loss: 0.0711 - acc: 0.9270 - val_loss: 0.0785 - val_acc: 0.9163
#
# Epoch 00078: val_acc did not improve from 0.91868
# Epoch 79/100
# 9612/9612 [==============================] - 3s 363us/step - loss: 0.0699 - acc: 0.9271 - val_loss: 0.0779 - val_acc: 0.9163
#
# Epoch 00079: val_acc did not improve from 0.91868
# Epoch 80/100
# 9612/9612 [==============================] - 3s 341us/step - loss: 0.0701 - acc: 0.9282 - val_loss: 0.0778 - val_acc: 0.9169
# Epoch 00080: val_acc did not improve from 0.91868
# Epoch 81/100
# 9612/9612 [==============================] - 4s 376us/step - loss: 0.0699 - acc: 0.9275 - val_loss: 0.0780 - val_acc: 0.9163
#
# Epoch 00081: val_acc did not improve from 0.91868
# Epoch 82/100
# 9612/9612 [==============================] - 4s 400us/step - loss: 0.0693 - acc: 0.9285 - val_loss: 0.0774 - val_acc: 0.9216
#
# Epoch 00082: val_acc improved from 0.91868 to 0.92163, saving model to weights.hdf5
# Epoch 83/100
# 9612/9612 [==============================] - 4s 385us/step - loss: 0.0695 - acc: 0.9287 - val_loss: 0.0772 - val_acc: 0.9204
#
# Epoch 00083: val_acc did not improve from 0.92163
# Epoch 84/100
# 9612/9612 [==============================] - 3s 327us/step - loss: 0.0691 - acc: 0.9293 - val_loss: 0.0773 - val_acc: 0.9187
#
# Epoch 00084: val_acc did not improve from 0.92163
# Epoch 85/100
# 9612/9612 [==============================] - 3s 320us/step - loss: 0.0696 - acc: 0.9282 - val_loss: 0.0771 - val_acc: 0.9199
#
# Epoch 00085: val_acc did not improve from 0.92163
# Epoch 86/100
# 9612/9612 [==============================] - 3s 323us/step - loss: 0.0695 - acc: 0.9279 - val_loss: 0.0769 - val_acc: 0.9193
#
# Epoch 00086: val_acc did not improve from 0.92163
# Epoch 87/100
# 9612/9612 [==============================] - 3s 333us/step - loss: 0.0689 - acc: 0.9290 - val_loss: 0.0767 - val_acc: 0.9210
#
# Epoch 00087: val_acc did not improve from 0.92163
# Epoch 88/100
# 9612/9612 [==============================] - 3s 328us/step - loss: 0.0685 - acc: 0.9309 - val_loss: 0.0767 - val_acc: 0.9222
#
# Epoch 00088: val_acc improved from 0.92163 to 0.92222, saving model to weights.hdf5
# Epoch 89/100
# 9612/9612 [==============================] - 3s 311us/step - loss: 0.0682 - acc: 0.9313 - val_loss: 0.0770 - val_acc: 0.9204
#
# Epoch 00089: val_acc did not improve from 0.92222
# Epoch 90/100
# 9612/9612 [==============================] - 3s 321us/step - loss: 0.0682 - acc: 0.9310 - val_loss: 0.0771 - val_acc: 0.9234
#
# Epoch 00090: val_acc improved from 0.92222 to 0.92339, saving model to weights.hdf5
# Epoch 91/100
# 9612/9612 [==============================] - 3s 333us/step - loss: 0.0680 - acc: 0.9316 - val_loss: 0.0766 - val_acc: 0.9234
#
# Epoch 00091: val_acc did not improve from 0.92339
# Epoch 92/100
# 9612/9612 [==============================] - 3s 331us/step - loss: 0.0680 - acc: 0.9316 - val_loss: 0.0767 - val_acc: 0.9199
#
# Epoch 00092: val_acc did not improve from 0.92339
# Epoch 93/100
# 9612/9612 [==============================] - 3s 337us/step - loss: 0.0677 - acc: 0.9315 - val_loss: 0.0768 - val_acc: 0.9228
#
# Epoch 00093: val_acc did not improve from 0.92339
# Epoch 94/100
# 9612/9612 [==============================] - 3s 357us/step - loss: 0.0677 - acc: 0.9324 - val_loss: 0.0771 - val_acc: 0.9210
#
# Epoch 00094: val_acc did not improve from 0.92339
# Epoch 95/100
# 9612/9612 [==============================] - 3s 353us/step - loss: 0.0682 - acc: 0.9303 - val_loss: 0.0770 - val_acc: 0.9222
#
# Epoch 00095: val_acc did not improve from 0.92339
# Epoch 96/100
# 9612/9612 [==============================] - 4s 399us/step - loss: 0.0677 - acc: 0.9323 - val_loss: 0.0767 - val_acc: 0.9222
#
# Epoch 00096: val_acc did not improve from 0.92339
# Epoch 97/100
# 9612/9612 [==============================] - 3s 358us/step - loss: 0.0676 - acc: 0.9315 - val_loss: 0.0764 - val_acc: 0.9228
#
# Epoch 00097: val_acc did not improve from 0.92339
# Epoch 98/100
# 9612/9612 [==============================] - 4s 403us/step - loss: 0.0680 - acc: 0.9312 - val_loss: 0.0771 - val_acc: 0.9216
#
# Epoch 00098: val_acc did not improve from 0.92339
# Epoch 99/100
# 9612/9612 [==============================] - 4s 464us/step - loss: 0.0682 - acc: 0.9302 - val_loss: 0.0775 - val_acc: 0.9204
#
# Epoch 00099: val_acc did not improve from 0.92339
# Epoch 100/100
# 9612/9612 [==============================] - 3s 355us/step - loss: 0.0677 - acc: 0.9314 - val_loss: 0.0780 - val_acc: 0.9204
#
# Epoch 00100: val_acc did not improve from 0.92339
